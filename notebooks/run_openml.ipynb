# %%
import project_path

from run_openml import run

# %%
run('gaussian', small_test=True)
# Out:
# INFO:thesis:====================
# INFO:thesis:Experiment gaussian
# INFO:thesis:====================
# INFO:root:Starting [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:root:0.1108840s taken for [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:thesis:Evaluating dataset boston...
# INFO:thesis:Computing model MLE Gaussian...
# 100%|██████████| 2/2 [00:02<00:00,  1.50s/it]
# INFO:thesis:Computing model Quantile-based PI...
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# INFO:thesis:Computing model HQPI...
# 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# ### boston
# 3.025605146842726
# <class 'numpy.float64'>
# 6.721413786091254
# <class 'numpy.float64'>
# 59.37692951204277
# <class 'numpy.float64'>
# 2.5488644806144833
# <class 'numpy.float64'>
# 3.1546001273686852
# <class 'numpy.float64'>
# 4.3130771659389096
# <class 'numpy.float64'>
# 30.030318578658058
# <class 'numpy.float64'>
# 56.239419066079
# ...

# %%
run('gaussian', small_test=True)
# Out:
# ERROR:root:File `"('gaussian',.py"` not found.

# %%
run('bimodal', small_test=True)
# Out:
# INFO:root:Starting [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:root:0.1063635s taken for [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:thesis:Evaluating dataset boston...
# INFO:thesis:Computing model MLE Gaussian...
# 100%|██████████| 2/2 [00:03<00:00,  1.62s/it]
# ### boston
#                                Log score                    Epochs  \
# Model
# MLE Gaussian  \textbf{2.60 $\pm$ 0.0715}  \textbf{5.00 $\pm$ 0.00}
#
#                       Training time (s)              Prediction time (s)
# Model
# MLE Gaussian  \textbf{1.52 $\pm$ 0.124}  \textbf{0.00444 $\pm$ 0.000330}
# INFO:thesis:Evaluating dataset Moneyball...
# INFO:thesis:Computing model MLE Gaussian...
# 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# ### Moneyball
#                                Log score                    Epochs  \
# Model
# MLE Gaussian  \textbf{4.58 $\pm$ 0.0168}  \textbf{4.00 $\pm$ 1.00}
#
# ...

# %%
run('calibration', small_test=True)
# Out:
# INFO:root:Starting [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:root:0.1086967s taken for [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:thesis:Evaluating dataset boston...
# INFO:thesis:Computing model MLE Gaussian...
# 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]x_cal:  0.00225735310817608 0.9999999985795975
# y_cal:  0.0 1.0
# x_cal:  0.00022569673907297573 0.9995655634387802
# y_cal:  0.0 1.0
# ### boston
#                              L2 cal. (before)                 L2 cal. (after)  \
# Model
# MLE Gaussian  \textbf{0.00210 $\pm$ 0.000577}  \textbf{0.00190 $\pm$ 0.00102}
#
#                                  Epochs          Training time (s)  \
# Model
# MLE Gaussian  \textbf{4.50 $\pm$ 0.500}  \textbf{1.36 $\pm$ 0.223}
#
#                           Prediction time (s)
# Model
# MLE Gaussian  \textbf{0.00371 $\pm$ 0.000133}
# INFO:thesis:Evaluating dataset Moneyball...
# INFO:thesis:Computing model MLE Gaussian...
# ...

# %%
run('gaussian', small_test=True)
# Out:
# INFO:root:Starting [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:root:0.3105907s taken for [get] request for the URL https://www.openml.org/api/v1/xml/study/269
# INFO:thesis:Evaluating dataset boston...
# INFO:thesis:Computing model MLE Gaussian...
# 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# INFO:thesis:Computing model Quantile-based PI...
# 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# INFO:thesis:Computing model HQPI...
# 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]
# INFO:thesis:Computing model NGBoost...
# 100%|██████████| 2/2 [00:07<00:00,  3.66s/it]
# ### boston
#                              Interval score                         CRPS  \
# Model
# MLE Gaussian       \textbf{18.9 $\pm$ 2.66}  \textbf{1.82 $\pm$ 0.00489}
# Quantile-based PI           21.2 $\pm$ 3.28            2.55 $\pm$ 0.0113
# HQPI                        50.2 $\pm$ 8.82             3.87 $\pm$ 0.120
# ...
